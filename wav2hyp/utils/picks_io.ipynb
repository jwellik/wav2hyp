# %%
from io import EQTOutput

# %%
eqt_output = EQTOutput("/home/jwellik/PROJECTS/PHASE_PICKS/seisbench_tutorials/wav2hyp-basic/results/sthelens/picks/eqt-volpick/eqt-volpick.h5")

# %%
picks, detections, md = eqt_output.read()
# Out:
# Reading EQT output from /home/jwellik/PROJECTS/PHASE_PICKS/seisbench_tutorials/wav2hyp-basic/results/sthelens/picks/eqt-volpick/eqt-volpick.h5

# %%
picks
# Out:
# PickList with 43675 entries:
#
# UW.HSR.	2021-06-29T00:00:19.600140Z	S
# UW.HSR.	2021-06-29T00:00:14.370140Z	S
# UW.HSR.	2021-06-29T00:00:19.260140Z	S
# ...
# UW.TDL.	2021-06-29T23:59:51.400142Z	S
# UW.TDL.	2021-06-29T23:59:51.080142Z	S
# UW.TDL.	2021-06-29T23:59:51.080142Z	P

# %%
# Out:
# sb.PickListX
